# %% [markdown]
# # Final Models

# %% [markdown]
# ## Multiple Linear Regression

# %% [markdown]
# ### Significant Features from initial LR

# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
lr_df = pd.read_csv('../Data/lr_sig_df.csv')
lr_df.drop(columns=['Unnamed: 0'], inplace = True)
lr_df
# Out:
#     Per_No_High_School_Diploma  per_hisp  per_black    MEDINC  \
# 0                    -0.284826 -0.273202  -0.257450 -0.472793
# 1                    -0.162622 -0.245387  -0.659805 -0.052162
# 2                    -0.651440 -0.417658  -0.491639 -0.054291
# 3                    -0.741057 -0.313668  -0.885502  0.773854
# 4                    -1.319491 -0.528408  -0.896730  2.667351
# ..                         ...       ...        ...       ...
# 72                   -0.488501 -0.912641   1.527001 -0.208887
# 73                   -1.392814 -0.582486  -0.879028  1.380378
# 74                   -0.871408 -0.803684   0.638185  0.170859
# 75                   -0.863261 -0.663677  -0.790976  0.037901
# 76                   -1.026200 -0.384876  -0.617559 -0.039712
#
#     Per_Unemployment  stop_dens_sqmi
# 0          -0.836434       54.891304
# 1          -0.778808       55.524079
# 2          -0.807621       76.724138
# 3          -0.937281       53.125000
# ...

# %%
dt_df = pd.read_csv('../Data/dt_imp.csv')
dt_df.drop(columns=['Unnamed: 0'], inplace= True)
dt_df.head()
# Out:
#    pop_dens_sqmi  2020_HH_SIZE  Per_Unemployment    MEDINC  per_other  \
# 0       2.301314     -1.128451         -0.836434 -0.472793   1.301235
# 1       1.165326      0.665484         -0.778808 -0.052162   2.157760
# 2       1.544641     -1.681458         -0.807621 -0.054291   0.702641
# 3       0.348444     -0.903859         -0.937281  0.773854   2.268745
# 4       0.526030     -0.368961         -1.268633  2.667351   1.638710
#
#    stop_dens_sqmi
# 0       54.891304
# 1       55.524079
# 2       76.724138
# 3       53.125000
# 4       56.097561

# %%
dt_df.rename(columns={'2020_HH_SIZE': 'hh_size'}, inplace=True)
dt_df.head()
# Out:
#    pop_dens_sqmi   hh_size  Per_Unemployment    MEDINC  per_other  \
# 0       2.301314 -1.128451         -0.836434 -0.472793   1.301235
# 1       1.165326  0.665484         -0.778808 -0.052162   2.157760
# 2       1.544641 -1.681458         -0.807621 -0.054291   0.702641
# 3       0.348444 -0.903859         -0.937281  0.773854   2.268745
# 4       0.526030 -0.368961         -1.268633  2.667351   1.638710
#
#    stop_dens_sqmi
# 0       54.891304
# 1       55.524079
# 2       76.724138
# 3       53.125000
# 4       56.097561

# %%
#Linear Regressio using ordinary least squares as error
model = smf.ols("""stop_dens_sqmi ~ Per_No_High_School_Diploma + per_hisp + per_black + MEDINC + Per_Unemployment""", 
                data = lr_df).fit()

#Results of model
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         stop_dens_sqmi   R-squared:                       0.083
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     1.287
# Date:                Fri, 14 Apr 2023   Prob (F-statistic):              0.279
# Time:                        09:23:30   Log-Likelihood:                -332.57
# No. Observations:                  77   AIC:                             677.1
# Df Residuals:                      71   BIC:                             691.2
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
#Linear Regressio using ordinary least squares as error
model = smf.ols("""stop_dens_sqmi ~ pop_dens_sqmi + hh_size + Per_Unemployment + MEDINC + per_other""", 
                data = dt_df).fit()

#Results of model
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         stop_dens_sqmi   R-squared:                       0.614
# Model:                            OLS   Adj. R-squared:                  0.587
# Method:                 Least Squares   F-statistic:                     22.56
# Date:                Fri, 14 Apr 2023   Prob (F-statistic):           1.78e-13
# Time:                        09:26:57   Log-Likelihood:                -299.28
# No. Observations:                  77   AIC:                             610.6
# Df Residuals:                      71   BIC:                             624.6
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...
